# %%
import pandas as pd

# %%
df = pd.read_csv("Default.csv")

# %%
df.head()
# Out:
#   default student      balance       income
# 0      No      No   729.526495  44361.62507
# 1      No     Yes   817.180407  12106.13470
# 2      No      No  1073.549164  31767.13895
# 3      No      No   529.250605  35704.49394
# 4      No      No   785.655883  38463.49588

# %%
df.isna().sum()
# Out:
# default    0
# student    0
# balance    0
# income     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(df["balance"])
# Out:
# <Axes: ylabel='balance'>

# %%
mean=df["balance"].mean()
std=df["balance"].std()

# %%
sns.histplot(data=df , x="balance" , kde=True)
plt.axvline(mean,color="red")
plt.axvline(mean+3*std , color ="blue")
plt.axvline(mean-3*std , color="blue")

# %%
df.loc[df["balance"] > mean+3*std]
# Out:
#      default student      balance        income
# 1136     Yes      No  2499.016750  51504.293960
# 1160     Yes     Yes  2502.684931  14947.519750
# 1502     Yes     Yes  2332.878254  11770.234120
# 2140      No     Yes  2308.893236  19110.266410
# 2929     Yes     Yes  2387.314867  28296.914720
# 3162     Yes     Yes  2415.316994  17429.503370
# 3702      No     Yes  2370.463612  24251.958720
# 3855     Yes     Yes  2321.882221  21331.314780
# 3913     Yes     Yes  2334.123559  19335.889290
# 3976      No     Yes  2388.174009   7832.135644
# 4231     Yes     Yes  2291.617688  20837.209450
# 6075     Yes      No  2413.319449  38540.572710
# 6334     Yes      No  2343.797513  51095.293930
# 6882     Yes     Yes  2287.173842  18692.144310
# 7437     Yes     Yes  2461.506979  11878.557040
# 7815     Yes     Yes  2578.469022  25706.647770
# 8495     Yes     Yes  2654.322576  21930.388880
# 8992     Yes     Yes  2352.054949  24067.548100
# 9873      No      No  2391.007739  50302.909560
# ...

# %%
df.drop(df[df["balance"] > mean+3*std].index , inplace=True)

# %%
# build model

# %%
df.drop("student" , axis =1 , inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.drop("student" , axis =1 , inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
x = df.drop("default",axis = 1)
y=df["default"]

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_ss = ss.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x , y,test_size=0.2 , random_state=20)

# %%
from sklearn.neighbors import KNeighborsClassifier
parameter = {"n_neighbors":[3,5,7,9,11,13,15],
             "metric" :["euclidean" , "minkowski"]}
knn = KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV
gsv=GridSearchCV(knn,param_grid = parameter)
gsv.fit(x_train , y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9, 11, 13, 15]})

# %%
gsv.best_params_
# Out:
# {'metric': 'euclidean', 'n_neighbors': 15}

# %%
model = KNeighborsClassifier(n_neighbors= 15 , metric= "euclidean")
model.fit(x_train , y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=15)

# %%
test_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score , confusion_matrix
accuracy_score(y_test , test_pred)
# Out:
# 0.969939879759519

# %%
res = confusion_matrix(y_test , test_pred)

# %%
pd.DataFrame(res,columns=["pred +ve " , "pred -ve" ] , index=["actual +ve" , "actual -ve"])
# Out:
#             pred +ve   pred -ve
# actual +ve       1935         0
# actual -ve         60         1

# %%
pip install imblearn
# Out:
# ...
#
#    ---------------------------------------- 0/3 [sklearn-compat]
#    ---------------------------------------- 0/3 [sklearn-compat]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
#    ------------- -------------------------- 1/3 [imbalanced-learn]
# ...

# %%
from sklearn.metrics import precision_score , recall_score

# %%
precision_score(y_test , test_pred , pos_label = "Yes")
# Out:
# 1.0

# %%
precision_score(y_test , test_pred , pos_label = "No")
# Out:
# 0.9699248120300752

# %%
recall_score(y_test , test_pred , pos_label = "Yes")
# Out:
# 0.01639344262295082

# %%
recall_score(y_test , test_pred , pos_label = "No")
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test , test_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.97      1.00      0.98      1935
#          Yes       1.00      0.02      0.03        61
#
#     accuracy                           0.97      1996
#    macro avg       0.98      0.51      0.51      1996
# weighted avg       0.97      0.97      0.96      1996

# %%
#  data is imbalanced
