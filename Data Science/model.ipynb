# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Salary_Data.csv")

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
plt.boxplot(data["YearsExperience"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x189460ecf50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x189460ed1d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x189460c0e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x189460ed450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x189460ed590>],
#  'means': []}

# %%
plt.boxplot(data["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18946199bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18946199e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18946199a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1894619a0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1894619a210>],
#  'means': []}

# %%
## ml  model data  spliting

# %%
x=data[["YearsExperience"]]
y=data["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state = 34)

# %%
x_train.shape
# Out:
# (24, 1)

# %%
y_train.shape
# Out:
# (24,)

# %% [markdown]
# ######## build model ########

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ######### test_model #############

# %%
test_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,test_pred)
# Out:
# 0.9244141448042442

# %% [markdown]
# ########### kind of deployment ############
#
# # accuracy is satisfy so we can deploy model
# # deploy means use model for prediction
# # use predict method

# %%
model.predict([[2.2]])
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45784.58586562])

# %%
# the values generated by model during training

# %%
model.intercept_
# Out:
# np.float64(24876.579738225664)

# %%
model.coef_
# Out:
# array([9503.63914882])

# %%
## we are visualizing the best fit linr drawn by algo during training

# %%
import matplotlib.pyplot as plt

# %%
# prediction values for training data

# %%
train_pred = model.predict(x_train)

# %%
plt.scatter(x_train , y_train)
plt.plot(x_train , train_pred , color="red" , marker = "o")

# %%
from sklearn.metrics import mean_squared_error , root_mean_squared_error
root_mean_squared_error(y_train , train_pred)
# Out:
# 5063.769773682688
