# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cars93.csv")

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     object
#  1   Model           93 non-null     object
#  2   Type            93 non-null     object
#  3   Price           93 non-null     float64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         79 non-null     object
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 7.4+ KB

# %%
df.isnull().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
m=df["AirBags"].mode()
m
# Out:
# 0    Driver only
# Name: AirBags, dtype: object

# %%
df["AirBags"]=df["AirBags"].fillna(m[0])

# %%
df.isnull().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags            0
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
mean =df["Price"].mean()

# %%
mo=df["Luggage.room"].mode()
mo
# Out:
# 0    14.0
# Name: Luggage.room, dtype: float64

# %%
df["Luggage.room"]=df["Luggage.room"].fillna(mo[0])

# %%
df=df.dropna()

# %%
mean=df["Price"].mean()
mean
std = df["Price"].std()
std
# Out:
# np.float64(9.464841566831739)

# %%
sns.histplot(data=df , x="Price",kde=True)
plt.axvline(mean,color = "red")
plt.axvline(mean+3*std,color = "purple")
plt.axvline(mean-3*std,color = "purple")

# %%
plt.boxplot(df["Price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f34ca0e210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1f34ca0e490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1f34ca0e0d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f34ca0e710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f34ca0e850>],
#  'means': []}

# %%
df[df["Price"] > (mean+3*std)]
# Out:
#      Manufacturer Model     Type  Price  MPG.city             AirBags  \
# 47       Infiniti   Q45  Midsize   47.9        17         Driver only
# 58  Mercedes-Benz  300E  Midsize   61.9        19  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 47         278           5            29.0          15.0
# 58         217           5            27.0          15.0

# %%
mean+3*std
# Out:
# np.float64(47.55826096423148)

# %%
df.loc[df["Price"] > (mean+3*std) ,"Price"]=47

# %%
sns.histplot(data = df , x="Price" , kde = True)
plt.axvline(mean , color = "red")
plt.axvline(mean+3*std )
plt.axvline(mean-3*std)

# %%
df["Model"].unique()
# Out:
# array(['Integra', 'Legend', '90', '100', '535i', 'Century', 'LeSabre',
#        'Roadmaster', 'Riviera', 'DeVille', 'Seville', 'Cavalier',
#        'Corsica', 'Camaro', 'Lumina', 'Lumina_APV', 'Astro', 'Caprice',
#        'Concorde', 'LeBaron', 'Imperial', 'Colt', 'Shadow', 'Spirit',
#        'Caravan', 'Dynasty', 'Stealth', 'Summit', 'Vision', 'Festiva',
#        'Escort', 'Tempo', 'Mustang', 'Probe', 'Aerostar', 'Taurus',
#        'Crown_Victoria', 'Metro', 'Storm', 'Prelude', 'Civic', 'Accord',
#        'Excel', 'Elantra', 'Scoupe', 'Sonata', 'Q45', 'ES300', 'SC300',
#        'Continental', 'Town_Car', '323', 'Protege', '626', 'MPV', '190E',
#        '300E', 'Capri', 'Cougar', 'Mirage', 'Diamante', 'Sentra',
#        'Altima', 'Quest', 'Maxima', 'Achieva', 'Cutlass_Ciera',
#        'Silhouette', 'Eighty-Eight', 'Laser', 'LeMans', 'Sunbird',
#        'Firebird', 'Grand_Prix', 'Bonneville', '900', 'SL', 'Justy',
# ...

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
df1 = df.drop("Manufacturer", axis = 1)
df2 = df.drop("Type", axis = 1)
df3 = df.drop("AirBags", axis = 1)

# %%
df3.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city  Horsepower  Passengers  \
# 0        Acura  Integra    Small   15.9        25         140           5
# 1        Acura   Legend  Midsize   33.9        18         200           5
# 2         Audi       90  Compact   29.1        20         172           5
# 3         Audi      100  Midsize   37.7        19         172           6
# 4          BMW     535i  Midsize   30.0        22         208           4
#
#    Rear.seat.room  Luggage.room
# 0            26.5          11.0
# 1            30.0          15.0
# 2            28.0          14.0
# 3            31.0          17.0
# 4            27.0          13.0

# %%
df_num = df.select_dtypes(include=["number"])
df_num
# Out:
#     Price  MPG.city  Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0    15.9        25         140           5            26.5          11.0
# 1    33.9        18         200           5            30.0          15.0
# 2    29.1        20         172           5            28.0          14.0
# 3    37.7        19         172           6            31.0          17.0
# 4    30.0        22         208           4            27.0          13.0
# ..    ...       ...         ...         ...             ...           ...
# 88   19.7        17         109           7            34.0          14.0
# 89   20.0        21         134           5            31.5          14.0
# 90   23.3        18         178           4            26.0          15.0
# 91   22.7        21         114           5            29.5          14.0
# 92   26.7        20         168           5            30.0          15.0
#
# [91 rows x 6 columns]

# %%
df_num.corr()
# Out:
#                    Price  MPG.city  Horsepower  Passengers  Rear.seat.room  \
# Price           1.000000 -0.615653    0.801972    0.208148        0.340110
# MPG.city       -0.615653  1.000000   -0.677249   -0.540669       -0.384347
# Horsepower      0.801972 -0.677249    1.000000    0.214779        0.256732
# Passengers      0.208148 -0.540669    0.214779    1.000000        0.694134
# Rear.seat.room  0.340110 -0.384347    0.256732    0.694134        1.000000
# Luggage.room    0.386150 -0.470688    0.356768    0.474397        0.591331
#
#                 Luggage.room
# Price               0.386150
# MPG.city           -0.470688
# Horsepower          0.356768
# Passengers          0.474397
# Rear.seat.room      0.591331
# Luggage.room        1.000000

# %%
sns.heatmap(df_num.corr() ,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Type"]=le.fit_transform(df["Type"])

# %%
df.head()
# Out:
#   Manufacturer    Model  Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra     3   15.9        25         Driver only
# 1        Acura   Legend     2   33.9        18  Driver & Passenger
# 2         Audi       90     0   29.1        20         Driver only
# 3         Audi      100     2   37.7        19  Driver & Passenger
# 4          BMW     535i     2   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
od = OrdinalEncoder(categories = [["Compact","Small","Midsize","Sporty","Large","Van"]])

# %%
df["Type"] = od.fit_transform(df[["Type"]]).astype("int")

# %%
df.head()
