# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
net = pd.read_csv("netflix_titles.csv")

# %%
net.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
net.shape
# Out:
# (8807, 12)

# %%
net.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
net.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
net=net.dropna()

# %%
net.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
typ=net["type"].value_counts()
typ
# Out:
# type
# Movie      5185
# TV Show     147
# Name: count, dtype: int64

# %%
plt.bar(typ.index , typ.values)
# Out:
# <BarContainer object of 2 artists>

# %%
net.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
rate=net["rating"].value_counts().head()
rate
# Out:
# rating
# TV-MA    1822
# TV-14    1214
# R         778
# PG-13     470
# TV-PG     431
# Name: count, dtype: int64

# %%
plt.pie(rate.values,labels = rate.index ,autopct="%0.2f%%")
plt.show()

# %%
ry=net["release_year"].value_counts()
ry
# Out:
# release_year
# 2017    657
# 2018    648
# 2016    577
# 2019    519
# 2020    442
#        ...
# 1945      1
# 1946      1
# 1942      1
# 1947      1
# 1944      1
# Name: count, Length: 72, dtype: int64

# %%
plt.plot(ry.index , ry.values)

# %%
net["duration"].value_counts()
# Out:
# duration
# 94 min     135
# 93 min     130
# 97 min     129
# 95 min     127
# 90 min     123
#           ...
# 228 min      1
# 18 min       1
# 205 min      1
# 201 min      1
# 191 min      1
# Name: count, Length: 198, dtype: int64

# %%
movie_df = net[net['type'] =='Movie'].copy()
movie_df["duration_int"] = movie_df["duration"].str.replace('min','').astype(int)
plt.hist(movie_df["duration_int"],bins=30)
plt.xlabel("duration(min)")
plt.ylabel("number of movies")
# Out:
# Text(0, 0.5, 'number of movies')

# %%
net.head()
# Out:
#    show_id     type                          title             director  \
# 7       s8    Movie                        Sankofa         Haile Gerima
# 8       s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9      s10    Movie                   The Starling       Theodore Melfi
# 12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 24     s25    Movie                          Jeans           S. Shankar
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24  Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
#
#                                               country          date_added  \
# 7   United States, Ghana, Burkina Faso, United Kin...  September 24, 2021
# ...

# %%
net.["show_id"].count()

# %%
cnt=net["country"].value_counts().head(10)
cnt
# Out:
# country
# United States     1846
# India              875
# United Kingdom     183
# Canada             107
# Spain               91
# Egypt               90
# Nigeria             88
# Japan               83
# Turkey              79
# Indonesia           76
# Name: count, dtype: int64

# %%
plt.barh(cnt.index , cnt.values )
# Out:
# <BarContainer object of 10 artists>

# %%
release_cnt = net["release_year"].value_counts()

# %%
release_cnt
# Out:
# release_year
# 2017    657
# 2018    648
# 2016    577
# 2019    519
# 2020    442
#        ...
# 1945      1
# 1946      1
# 1942      1
# 1947      1
# 1944      1
# Name: count, Length: 72, dtype: int64

# %%
plt.scatter(release_cnt.index , release_cnt.values)

# %%
cby=net.groupby(["release_year","type"]).size().unstack().fillna(0)

# %%
cby
# Out:
# type          Movie  TV Show
# release_year
# 1942            1.0      0.0
# 1944            1.0      0.0
# 1945            1.0      0.0
# 1946            1.0      0.0
# 1947            1.0      0.0
# ...             ...      ...
# 2017          640.0     17.0
# 2018          632.0     16.0
# 2019          495.0     24.0
# 2020          409.0     33.0
# 2021          146.0     15.0
#
# [72 rows x 2 columns]

# %%
fig,ax = plt.subplots(1,2,figsize=(12,5))
ax[0].plot(cby.index , cby["Movie"])

ax[1].plot(cby.index , cby["TV Show"])
